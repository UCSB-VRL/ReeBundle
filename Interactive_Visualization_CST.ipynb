# %%
import nibabel as nib
import numpy as np
from dipy.io.streamline import load_tractogram, save_tractogram
import robustReebConstruction as rc
import os
import pickle
import networkx as nx
import visualization as vis
import plotly.graph_objects as go
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
 # %%time
trkpathI = "/media/hdd2/shailja/Crash/CSTsphere1brush6/sub-4936m_ses-6_DSI_mc.src.gz.odf8.f5rec.gqi.1.25.cst.trk.gz"    
p_streamlines =  nib.streamlines.load(trkpathI)
print("n = ",len(p_streamlines.streamlines))
count = 0
streamlines = p_streamlines.streamlines
#Step 2: Reeb Graph Construction
eps =2.5
alpha = 3
delta = 2

H, node_loc = rc.constructRobustReeb(streamlines, eps, alpha, delta)
G = H

# 3d spring layout
pos = node_loc
# Extract node and edge positions from the layout
node_xyz = np.array([pos[v] for v in sorted(G)])
edge_xyz = np.array([(pos[u], pos[v]) for u, v in G.edges()])
edge_labels = nx.get_edge_attributes(G, "weight")
weight_labels = list(edge_labels.values())
# Out:
# n =  114
# CPU times: user 17.1 s, sys: 192 ms, total: 17.3 s
# Wall time: 16.9 s

# %%
#we need to seperate the X,Y,Z coordinates for Plotly
x_nodes = [node_loc[i][0] for i in H.nodes()]# x-coordinates of nodes
y_nodes = [node_loc[i][1] for i in H.nodes()]# y-coordinates
z_nodes = [node_loc[i][2] for i in H.nodes()]# z-coordinates

# %%
#We also need a list of edges to include in the plot
edge_list = H.edges()

# %%
#we  need to create lists that contain the starting and ending coordinates of each edge.
x_edges=[]
y_edges=[]
z_edges=[]

#need to fill these with all of the coordiates
for edge in edge_list:
    #format: [beginning,ending,None]
    x_coords = [node_loc[edge[0]][0],node_loc[edge[1]][0],None]
    x_edges.append(x_coords)

    y_coords = [node_loc[edge[0]][1],node_loc[edge[1]][1],None]
    y_edges.append(y_coords)

    z_coords = [node_loc[edge[0]][2],node_loc[edge[1]][2],None]
    z_edges.append(z_coords)

# %%
edge_labels.values()
weight_labels = list(edge_labels.values())

# %%
traces = []
for i in range(len(x_edges)):
    trace_edges = go.Scatter3d(x=x_edges[i],
                               y=y_edges[i],
                               z=z_edges[i],
                               mode='lines',
                               line=dict(color='black', width=weight_labels[i]*10),)
    traces.append(trace_edges)

# %%
xdata = []
ydata = []
zdata = [] 
for i in range(len(streamlines)):
    
    for j in streamlines[i]:
        xdata.append(j[0])
        ydata.append(j[1])
        zdata.append(j[2])
trace_data = go.Scatter3d(x=xdata,
                        y=ydata,
                        z=zdata,
                        mode='markers',
                        marker=dict(symbol='circle',color='#eb7a30', size=1),
                        hoverinfo=None)

# %%
#create a trace for the nodes
trace_nodes = go.Scatter3d(x=x_nodes,
                         y=y_nodes,
                        z=z_nodes,
                        mode='markers',                
                        marker=dict(symbol='circle',
                                    color = 'red',
                                    size=10,
                                    line=dict(color='red', width=0.5)),
                        
                        hoverinfo='text')

# %%
#we need to set the axis for the plot 
axis = dict(showbackground=False,
            showline=False,
            zeroline=False,
            showgrid=False,
            showticklabels=False,
            title='')

# %%
#also need to create the layout for our plot
layout = go.Layout(title= r'$\text{Corticospinal Tract (CST): } \epsilon = 2.5, \alpha = 3, \delta = 5$',
                width=650,
                height=625,
                showlegend=False,
                scene=dict(xaxis=dict(axis),
                        yaxis=dict(axis),
                        zaxis=dict(axis),
                        ),
                margin=dict(t=100),
                hovermode='closest')

# %%
#Include the traces we want to plot and create a figure
data = traces + [trace_nodes, trace_data]
fig = go.Figure(data=data, layout=layout)
fig.show()
# Out:
# <div>                            <div id="7cf76de0-eba6-4b40-bdb9-6ac74202ce97" class="plotly-graph-div" style="height:625px; width:650px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7cf76de0-eba6-4b40-bdb9-6ac74202ce97")) {                    Plotly.newPlot(                        "7cf76de0-eba6-4b40-bdb9-6ac74202ce97",                        [{"line":{"color":"black","width":1.6666666666666665},"mode":"lines","x":[106.20187835693359,105.75073208974467,null],"y":[114.3342269897461,110.30805140932401,null],"z":[102.66308898925782,98.70939640137885,null],"type":"scatter3d"},{"line":{"color":"black","width":4.912280701754385},"mode":"lines","x":[105.75073208974467,114.41047277969054,null],"y":[110.30805140932401,107.66010885236905,null],"z":[98.70939640137885,114.31544960989939,null],"type":"scatter3d"},{"line":{"color":"black","width":1.6666666666666665},"mode":"lines","x":[105.75073208974467,103.10459474541923,null],"y":[110.30805140932401,108.33304765820503,null],"z":[98.70939640137885,90.19673361073842,null],"type":"scatter3d"},{"line":{"color":"black","width":0.7017543859649122},"mode":"lines","x":[105.75073208974467,107.84625053405762,null],"y":[110.30805140932401,114.3377513885498,null],"z":[98.70939640137885,105.06405830383301,null],"type":"scatter3d"},{"line":{"color":"black","width":3.333333333333333},"mode":"lines","x":[114.41047277969054,113.32169227600097,null],"y":[107.66010885236905,107.68760871887207,null],"z":[114.31544960989939,111.63740768432618,null],"type":"scatter3d"},{"line":{"color":"black","width":6.4035087719298245},"mode":"lines","x":[114.41047277969054,116.87761022082701,null],"y":[107.66010885236905,106.1588192343625,null],"z":[114.31544960989939,121.71253763689944,null],"type":"scatter3d"},{"line":{"color":"black","width":7.192982456140351},"mode":"lines","x":[116.87761022082701,125.89353024482608,null],"y":[106.1588192343625,111.03935457634117,null],"z":[121.71253763689944,132.0817747233288,null],"type":"scatter3d"},{"line":{"color":"black","width":8.771929824561402},"mode":"lines","x":[125.89353024482608,119.48264811028504,null],"y":[111.03935457634117,96.4086023881062,null],"z":[132.0817747233288,154.16238382265095,null],"type":"scatter3d"},{"line":{"color":"black","width":1.4035087719298245},"mode":"lines","x":[125.89353024482608,129.08357095718384,null],"y":[111.03935457634117,116.80310217539468,null],"z":[132.0817747233288,124.67744795481363,null],"type":"scatter3d"},{"line":{"color":"black","width":1.2280701754385963},"mode":"lines","x":[119.48264811028504,113.52104187011719,null],"y":[96.4086023881062,100.93487071990967,null],"z":[154.16238382265095,147.7143669128418,null],"type":"scatter3d"},{"line":{"color":"black","width":0.43859649122807015},"mode":"lines","x":[119.48264811028504,143.2421875,null],"y":[96.4086023881062,95.6169204711914,null],"z":[154.16238382265095,160.4597930908203,null],"type":"scatter3d"},{"line":{"color":"black","width":0.2631578947368421},"mode":"lines","x":[119.48264811028504,136.62416076660156,null],"y":[96.4086023881062,96.06157684326172,null],"z":[154.16238382265095,170.88824462890625,null],"type":"scatter3d"},{"line":{"color":"black","width":0.2631578947368421},"mode":"lines","x":[119.48264811028504,120.8393325805664,null],"y":[96.4086023881062,100.16889190673828,null],"z":[154.16238382265095,151.6734161376953,null],"type":"scatter3d"},{"line":{"color":"black","width":0.3508771929824561},"mode":"lines","x":[119.48264811028504,144.4256591796875,null],"y":[96.4086023881062,100.71830749511719,null],"z":[154.16238382265095,156.0062255859375,null],"type":"scatter3d"},{"line":{"color":"black","width":2.017543859649123},"mode":"lines","x":[119.48264811028504,117.71459749009874,null],"y":[96.4086023881062,95.22554567125108,null],"z":[154.16238382265095,156.7829115125868,null],"type":"sca ...
